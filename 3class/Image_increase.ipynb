# %% [markdown]
# # DataLoading

# %%
import csv
import numpy as np
import pandas as pd
import cv2
import tensorflow as tf
import matplotlib.pyplot as plt
df= pd.read_csv("dataset.csv")
df = (df[df['K']>=5]).reset_index()

spiral = df[df['class']==2]

# %%
spiral[spiral['PATH'] == "Image/587733431919968557.jpg"]
# Out:
#    index  Unnamed: 0  class                          PATH          K  \
# 4      4           4      2  Image/587733431919968557.jpg  79.191522
#
#           C         A         S        G2         H
# 4  0.419185  0.816547  0.747687  0.223608  0.473116

# %%
#画像の回転
img_bgr = cv2.imread("Image/587733431919968557.jpg")
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

#
mat=cv2.getRotationMatrix2D(tuple(np.array(img_rgb.shape[:2])/2),45,1.0)

result_img=cv2.warpAffine(img_rgb,mat,img_rgb.shape[:2])

#
plt.imshow(result_img);
plt.show()

# %%
#色調変化
img_bgr = cv2.imread("Image/587733431919968557.jpg")
#
result_img = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2LAB)

#
plt.imshow(result_img);
plt.show()

# %%
#ぼかし
img_bgr = cv2.imread("Image/587733431919968557.jpg")
img_rgb= cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
#
result_img = cv2.GaussianBlur(img_rgb, (15,15),0)

#
plt.imshow(result_img);
plt.show()

# %%
#ノイズ除去
img_bgr = cv2.imread("Image/587733431919968557.jpg")
img_rgb= cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
#
result_img = cv2.fastNlMeansDenoisingColored(img_rgb)

#
plt.imshow(result_img);
plt.show()

# %%
#膨張
img_bgr = cv2.imread("Image/587733431919968557.jpg")
img_rgb= cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
#
filt=np.array([[0,1,0],
              [1,0,1],
              [0,1,0]], np.uint8)
#
result_img = cv2.dilate(img_rgb,filt)

#
plt.imshow(result_img);
plt.show()

# %%
#収縮
img_bgr = cv2.imread("Image/587733431919968557.jpg")
img_rgb= cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
#
filt=np.array([[0,1,0],
              [1,0,1],
              [0,1,0]], np.uint8)
#
result_img = cv2.erode(img_rgb,filt)

#
plt.imshow(result_img);
plt.show()

# %%
def img_mat(spiral):
    #回転
for i in range(len(spiral)):
    img_bgr = cv2.imread(spiral.PATH[i])
    img_rgb= cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    #画像の回転
    mat=cv2.getRotationMatrix2D(tuple(np.array(img_rgb.shape[:2])/2),45,1.0)
    result_img=cv2.warpAffine(img_rgb,mat,img_rgb.shape[:2])
# Out:
#        index  Unnamed: 0  class                          PATH           K  \
# 4          4           4      2  Image/587733431919968557.jpg   79.191522
# 33        33          33      2  Image/587739827676184942.jpg  138.826322
# 78        80          80      2  Image/587741709412073483.jpg  175.585689
# 206      214         214      2  Image/587746209447215183.jpg   89.143939
# 254      263         263      2  Image/587734861611466801.jpg   48.379849
# ...      ...         ...    ...                           ...         ...
# 19005  55639       55639      2  Image/587731874462499245.jpg   32.177785
# 19010  55662       55662      2  Image/588297864720744616.jpg   25.341540
# 19038  55762       55762      2  Image/587742013830004872.jpg   25.613377
# 19044  55778       55778      2  Image/588016840712782112.jpg   26.095923
# 19048  55786       55786      2  Image/588010360148394265.jpg   40.229055
#
#               C         A         S        G2         H
# ...

# %%
# Out:
#        index  Unnamed: 0  class                          PATH           K  \
# 4          4           4      2  Image/587733431919968557.jpg   79.191522
# 33        33          33      2  Image/587739827676184942.jpg  138.826322
# 78        80          80      2  Image/587741709412073483.jpg  175.585689
# 206      214         214      2  Image/587746209447215183.jpg   89.143939
# 254      263         263      2  Image/587734861611466801.jpg   48.379849
# ...      ...         ...    ...                           ...         ...
# 19005  55639       55639      2  Image/587731874462499245.jpg   32.177785
# 19010  55662       55662      2  Image/588297864720744616.jpg   25.341540
# 19038  55762       55762      2  Image/587742013830004872.jpg   25.613377
# 19044  55778       55778      2  Image/588016840712782112.jpg   26.095923
# 19048  55786       55786      2  Image/588010360148394265.jpg   40.229055
#
#               C         A         S        G2         H
# ...

# %%
from sklearn.model_selection import train_test_split
y = df['class']
x = df.drop('class',axis=1)

img_list = []
size = 64
#データを画像変換にリサイズする
for i in range(len(x)):
    img_data = cv2.imread(x.PATH[i])
    #img_data = cv2.cvtColor(img_data, cv2.COLOR_BGR2GRAY)  
    img_data = cv2.resize(img_data,(size,size))
    img_list.append(img_data)
X_train, X_test, y_train, y_test = train_test_split(img_list, y, test_size=0.2,random_state=1)
#X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.5, random_state=1)

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)
X_train = X_train.reshape(X_train.shape[0], size*size*3)
X_test = X_test.reshape(X_test.shape[0], size*size*3)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# %% [markdown]
# # 画像のかさまし

# %%
ls
# Out:
# GAN/
# GAN-NET.ipynb
# GAN_Image/
# Galaxy Zoo2 Report.ipynb
# Image/
# Image_bulk_K>=10/
# Image_bulk_K>=20/
# Image_bulk_K>=5/
# README.md
# X_train.npy
# dataset.csv
# training_checkpoints/
# 画像のかさまし DeepLearningモデル.ipynb
